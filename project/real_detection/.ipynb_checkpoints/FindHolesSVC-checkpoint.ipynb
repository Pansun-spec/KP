# %%
import cv2
import numpy as np
from skimage.io import imread, imsave
from matplotlib import pyplot as plt
from sklearn.svm import LinearSVC, SVC
from scipy import ndimage

# %%
def flatten_img(img):
    x, y, c = img.shape
    return img.reshape((x * y, c))

# %%
img = imread('res.jpg')
plt.imshow(img)

# %%
mask = imread('mask_svc.png')
# mask.png generate by GenTrainLabels.ipynb
plt.imshow(mask, cmap='gray')

# %%
img_tmp = img[:, :1000, :]
plt.imshow(img_tmp)

# %%
svc = LinearSVC()

# %%
# %%time
for x in range(1_000, 10_000, 1_000):
    img_tmp_flatten = flatten_img(img[:, x:x+1_000, :])
    mask_tmp_flatten = (mask[:, x:x+1_000] / 255).flatten()
    svc.fit(img_tmp_flatten, mask_tmp_flatten)
# Out:
# /home/kehua/.local/lib/python3.10/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/kehua/.local/lib/python3.10/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/kehua/.local/lib/python3.10/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/kehua/.local/lib/python3.10/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/kehua/.local/lib/python3.10/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/kehua/.local/lib/python3.10/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/kehua/.local/lib/python3.10/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/kehua/.local/lib/python3.10/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# CPU times: user 32.3 s, sys: 2.27 s, total: 34.6 s
# Wall time: 34.8 s
# /home/kehua/.local/lib/python3.10/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
# %%time
pred_svc = svc.predict(flatten_img(img))
# Out:
# CPU times: user 966 ms, sys: 4.16 s, total: 5.12 s
# Wall time: 4.1 s

# %%
img_mask = pred_svc.reshape(img.shape[0], img.shape[1]).astype(np.uint8)
plt.figure(figsize=(16, 9))
plt.imshow(img_mask, cmap='gray')

# %%
kernel_35 = np.zeros((35, 35), dtype=np.uint8)
cv2.circle(kernel_35, (17, 17), 17, (255,), -1)
plt.imshow(kernel_35, cmap='gray')

# %%
kernel_15 = np.zeros((15, 15), dtype=np.uint8)
cv2.circle(kernel_15, (7, 7), 7, (255,), -1)
plt.imshow(kernel_15, cmap='gray')

# %%
img_mask_erode = cv2.dilate(img_mask, kernel_15)
plt.figure(figsize=(16, 9))
plt.imshow(img_mask_erode, cmap='gray')

# %%
circles = cv2.HoughCircles(
        255 * img_mask_erode, # 8bit single-channel, grayscale input image
        cv2.HOUGH_GRADIENT, # Detection method
        2,                                              # Inverse ratio of the accmulator resolution to the image resolution
        130,                                         # Minimum distance of the two passed to the Canny edge detector
        param1 =100,                     # Higher threshold of the two passed to the  Canny edge detector
        param2 = 20,                      # The smaller it is , the more false circles may be detected
        minRadius=5,                    # Minimum circle radius
        maxRadius=50                 # Maximum circle radius
)

circles.shape
# Out:
# (1, 94, 3)

# %%
img_tmp = img.copy()
count = 0
r_pred = []
y_pred = []

for circle in circles[0]:
    center = (int(circle[0]),int(circle[1]))
    cv2.circle(img_tmp, center, 1, (0, 100, 100), 3)
    cv2.circle(img_tmp, center, int(circle[2]), (255, 0, 0), 7)
    cv2.putText(img_tmp, f'{str(count)} radius={round(circle[2] / 5)}mm ', center,
                    cv2.FONT_HERSHEY_COMPLEX, 2, (0, 255, 0), 2)
    print(f"{count + 1}.({circle[0]}, {circle[1]}), diameter: {round(circle[2] / 5)}")
    
    y_pred.append([circle[0], circle[1], circle[2]])
    r_pred.append(round(circle[2] / 5))
    r_pred.sort()
                  
    count += 1
img_tmp = ndimage.rotate(img_tmp, -90)
np.savetxt("pred_circles.txt", y_pred, fmt='%d', delimiter=',')
plt.figure(figsize=(18, 34))
plt.imshow(img_tmp)
# Out:
# 1.(6127.0, 919.0), diameter: 8
# 2.(2331.0, 3231.0), diameter: 8
# 3.(175.0, 4807.0), diameter: 10
# 4.(4711.0, 4083.0), diameter: 6
# 5.(4089.0, 3719.0), diameter: 8
# 6.(1867.0, 3597.0), diameter: 8
# 7.(3091.0, 1009.0), diameter: 8
# 8.(2847.0, 4893.0), diameter: 6
# 9.(815.0, 305.0), diameter: 10
# 10.(6379.0, 1043.0), diameter: 10
# 11.(9531.0, 215.0), diameter: 8
# 12.(9101.0, 3449.0), diameter: 8
# 13.(6799.0, 4161.0), diameter: 6
# 14.(7785.0, 1839.0), diameter: 6
# 15.(4697.0, 4493.0), diameter: 6
# 16.(5951.0, 2971.0), diameter: 10
# 17.(559.0, 881.0), diameter: 9
# 18.(9597.0, 3271.0), diameter: 6
# 19.(8945.0, 3001.0), diameter: 8
# 20.(639.0, 4049.0), diameter: 10
# 21.(1679.0, 2709.0), diameter: 8
# 22.(3779.0, 461.0), diameter: 7
# 23.(2783.0, 1353.0), diameter: 10
# 24.(6147.0, 3759.0), diameter: 8
# 25.(2703.0, 1817.0), diameter: 8
# 26.(9203.0, 2859.0), diameter: 7
# 27.(9409.0, 3477.0), diameter: 8
# 28.(2215.0, 185.0), diameter: 8
# 29.(1941.0, 1397.0), diameter: 10
# 30.(7265.0, 1603.0), diameter: 9
# 31.(7497.0, 2811.0), diameter: 10
# 32.(3995.0, 4049.0), diameter: 6
# 33.(5081.0, 2895.0), diameter: 5
# 34.(9795.0, 203.0), diameter: 8
# 35.(625.0, 3629.0), diameter: 6
# 36.(7993.0, 3893.0), diameter: 4
# 37.(4587.0, 3731.0), diameter: 8
# 38.(6141.0, 1173.0), diameter: 7
# 39.(4029.0, 4463.0), diameter: 6
# 40.(8227.0, 759.0), diameter: 10
# 41.(2359.0, 3443.0), diameter: 7
# 42.(4891.0, 4815.0), diameter: 10
# 43.(9109.0, 3711.0), diameter: 6
# 44.(8433.0, 3205.0), diameter: 9
# 45.(6675.0, 1433.0), diameter: 6
# 46.(8013.0, 3395.0), diameter: 4
# 47.(657.0, 4281.0), diameter: 9
# 48.(7349.0, 841.0), diameter: 10
# 49.(5823.0, 3367.0), diameter: 10
# 50.(6237.0, 3859.0), diameter: 6
# 51.(3409.0, 2059.0), diameter: 6
# 52.(4357.0, 3969.0), diameter: 9
# 53.(4531.0, 2323.0), diameter: 9
# 54.(5693.0, 181.0), diameter: 6
# 55.(6671.0, 203.0), diameter: 6
# 56.(4361.0, 2001.0), diameter: 9
# 57.(5039.0, 3467.0), diameter: 4
# 58.(6819.0, 1649.0), diameter: 10
# 59.(1605.0, 4767.0), diameter: 5
# 60.(639.0, 3837.0), diameter: 5
# 61.(8549.0, 4501.0), diameter: 4
# 62.(5907.0, 1175.0), diameter: 3
# 63.(7565.0, 3623.0), diameter: 10
# 64.(4027.0, 2221.0), diameter: 10
# 65.(3935.0, 1263.0), diameter: 9
# 66.(9499.0, 2991.0), diameter: 9
# 67.(4349.0, 4629.0), diameter: 8
# 68.(3533.0, 445.0), diameter: 3
# 69.(8905.0, 3227.0), diameter: 6
# 70.(2919.0, 1345.0), diameter: 2
# 71.(1057.0, 1487.0), diameter: 5
# 72.(9895.0, 4921.0), diameter: 5
# 73.(4973.0, 3595.0), diameter: 4
# 74.(179.0, 2015.0), diameter: 4
# 75.(213.0, 255.0), diameter: 4
# 76.(2815.0, 817.0), diameter: 4
# 77.(5901.0, 917.0), diameter: 3
# 78.(3819.0, 201.0), diameter: 3
# 79.(8795.0, 4515.0), diameter: 4
# 80.(3541.0, 193.0), diameter: 3
# 81.(9717.0, 1693.0), diameter: 2
# 82.(3535.0, 4313.0), diameter: 5
# 83.(2911.0, 2829.0), diameter: 3
# 84.(5111.0, 3589.0), diameter: 4
# 85.(1897.0, 3319.0), diameter: 3
# 86.(2903.0, 3729.0), diameter: 4
# 87.(2653.0, 1351.0), diameter: 3
# 88.(9117.0, 3969.0), diameter: 2
# 89.(8759.0, 829.0), diameter: 2
# 90.(543.0, 11.0), diameter: 2
# 91.(3443.0, 3179.0), diameter: 2
# 92.(2563.0, 2893.0), diameter: 2
# 93.(2093.0, 4893.0), diameter: 2
# 94.(7217.0, 835.0), diameter: 2

# %%
imsave('res_detection.png', img_tmp)
